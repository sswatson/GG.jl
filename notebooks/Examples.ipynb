2.2, 1.5, 1.4, 2.3, 2.4, 1.8, 1.8, 2.1, 2.4, 2.3, 1.9, 2.3, 2.5, 2.3, 1.9, 2.0, 2.3, 1.8],
                 Species = repeat(["setosa", "versicolor", "virginica"],inner=50));

# %%
ggplot(data = iris) +
    geom_point(aes(x = :SepalLength, y = :SepalWidth),
               alpha = 0.5,
               color = :black,
               fill = :green,
               size = 20)
# Out:
# GG.GGPlot(150×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species   │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ String    │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼───────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa    │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa    │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa    │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa    │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa    │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa    │
# │ 7   │ 4.6         │ 3.4        │ 1.4         │ 0.3        │ setosa    │
# │ 8   │ 5.0         │ 3.4        │ 1.5         │ 0.2        │ setosa    │
# │ 9   │ 4.4         │ 2.9        │ 1.4         │ 0.2        │ setosa    │
# ...

# %%
ggplot(data = iris, mapping = aes(x = :SepalLength, y = :SepalWidth, color = :Species)) +
    geom_jitter(size = 4, alpha = 0.5) + geom_path() + facet_wrap( ~ :Species)
# Out:
# GG.GGPlot(150×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species   │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ String    │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼───────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa    │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa    │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa    │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa    │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa    │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa    │
# │ 7   │ 4.6         │ 3.4        │ 1.4         │ 0.3        │ setosa    │
# │ 8   │ 5.0         │ 3.4        │ 1.5         │ 0.2        │ setosa    │
# │ 9   │ 4.4         │ 2.9        │ 1.4         │ 0.2        │ setosa    │
# ...

# %%
ggplot(data = iris) +
    geom_point(aes(x = :SepalLength, y = :SepalWidth, color = :PetalWidth),
               size = 4)
# Out:
# GG.GGPlot(150×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species   │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ String    │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼───────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa    │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa    │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa    │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa    │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa    │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa    │
# │ 7   │ 4.6         │ 3.4        │ 1.4         │ 0.3        │ setosa    │
# │ 8   │ 5.0         │ 3.4        │ 1.5         │ 0.2        │ setosa    │
# │ 9   │ 4.4         │ 2.9        │ 1.4         │ 0.2        │ setosa    │
# ...

# %%
n = 100
df = DataFrame(x = randn(n),
               y = randn(n),
               label = ["abcdefghijklmnopqrstuvwxyz"[rand(1:26)] for i=1:n],
               color = [(:blue,:red,:darkgreen)[rand(1:3)] for i=1:n],
               angle = [360*rand() for i=1:n])

ggplot(data = df) +
    geom_text(aes(x = :x, y = :y, label = :label, color = :color, angle = :angle))
# Out:
# GG.GGPlot(100×5 DataFrame
# │ Row │ x          │ y          │ label │ color     │ angle   │
# │     │ Float64    │ Float64    │ Char  │ Symbol    │ Float64 │
# ├─────┼────────────┼────────────┼───────┼───────────┼─────────┤
# │ 1   │ -0.0863188 │ 1.06885    │ 'i'   │ darkgreen │ 179.131 │
# │ 2   │ -0.634346  │ 0.803263   │ 'e'   │ darkgreen │ 265.07  │
# │ 3   │ -0.959425  │ -0.0183183 │ 'q'   │ blue      │ 125.919 │
# │ 4   │ 2.01974    │ 0.413343   │ 'l'   │ red       │ 62.1312 │
# │ 5   │ 0.0710428  │ 0.799428   │ 'x'   │ blue      │ 20.8215 │
# │ 6   │ 0.31201    │ -1.24988   │ 'l'   │ darkgreen │ 185.59  │
# │ 7   │ -0.0905584 │ -0.424516  │ 'c'   │ darkgreen │ 173.949 │
# │ 8   │ -0.819275  │ -1.34349   │ 's'   │ darkgreen │ 251.114 │
# │ 9   │ 1.09129    │ -0.654173  │ 's'   │ red       │ 221.071 │
# │ 10  │ -0.0679782 │ 0.0244991  │ 'j'   │ darkgreen │ 153.175 │
# ⋮
# │ 90  │ -0.542336  │ -1.06884   │ 'y'   │ darkgreen │ 285.323 │
# ...

# %%
ggplot() + geom_step(aes(x = 1:10, y = 1:10), direction = :vh)
# Out:
# GG.GGPlot(missing, missing, GG.Geom[GeomStep(Dict{Symbol,Any}(:mapping=>Aesthetic(Dict{Symbol,Any}(:y=>1:10,:x=>1:10)),:direction=>:vh))], GG.Theme(Dict{Symbol,Any}()), GG.Facet(Dict{Symbol,Any}()))

# %%
ggplot() + 
    geom_bar(aes(x = 1:10, y = rand(10)), label="foo") + 
    geom_bar(aes(x = 1:10, y = rand(10)), label="bar")
# Out:
# GG.GGPlot(missing, missing, GG.Geom[GeomBar(Dict{Symbol,Any}(:mapping=>Aesthetic(Dict{Symbol,Any}(:y=>[0.647461, 0.354851, 0.340038, 0.0890079, 0.371208, 0.299651, 0.844417, 0.48323, 0.700284, 0.854394],:x=>1:10)),:label=>"foo")), GeomBar(Dict{Symbol,Any}(:mapping=>Aesthetic(Dict{Symbol,Any}(:y=>[0.269257, 0.838592, 0.198089, 0.275053, 0.0907589, 0.646954, 0.702112, 0.236523, 0.797775, 0.191454],:x=>1:10)),:label=>"bar"))], GG.Theme(Dict{Symbol,Any}()), GG.Facet(Dict{Symbol,Any}()))

# %%
ggplot() + geom_ribbon(aes(x = 1:10, ymax = (1:10).^2 .+ 10, ymin = (1:10).^2 ./ 2),
                       fill = :orange, color = :MidnightBlue, size = 2, leg = :topleft)
# Out:
# GG.GGPlot(missing, missing, GG.Geom[GeomRibbon(Dict{Symbol,Any}(:color=>:MidnightBlue,:leg=>:topleft,:mapping=>Aesthetic(Dict{Symbol,Any}(:ymax=>[11, 14, 19, 26, 35, 46, 59, 74, 91, 110],:ymin=>[0.5, 2.0, 4.5, 8.0, 12.5, 18.0, 24.5, 32.0, 40.5, 50.0],:x=>1:10)),:fill=>:orange,:size=>2))], GG.Theme(Dict{Symbol,Any}()), GG.Facet(Dict{Symbol,Any}()))

# %%
df = DataFrame(x = [0,0,1,0,4,4,5,4], y = [0,1,0,0,4,5,4,4], tri = Any[1,1,1,1,2,2,2,2])

ggplot(data = df) + geom_polygon(aes(x = :x, y = :y, linetype = :tri), leg = :topleft)
# Out:
# GG.GGPlot(8×3 DataFrame
# │ Row │ x     │ y     │ tri │
# │     │ Int64 │ Int64 │ Any │
# ├─────┼───────┼───────┼─────┤
# │ 1   │ 0     │ 0     │ 1   │
# │ 2   │ 0     │ 1     │ 1   │
# │ 3   │ 1     │ 0     │ 1   │
# │ 4   │ 0     │ 0     │ 1   │
# │ 5   │ 4     │ 4     │ 2   │
# │ 6   │ 4     │ 5     │ 2   │
# │ 7   │ 5     │ 4     │ 2   │
# │ 8   │ 4     │ 4     │ 2   │, missing, GG.Geom[GeomPolygon(Dict{Symbol,Any}(:leg=>:topleft,:mapping=>Aesthetic(Dict{Symbol,Any}(:linetype=>:tri,:y=>:y,:x=>:x))))], GG.Theme(Dict{Symbol,Any}()), GG.Facet(Dict{Symbol,Any}()))
